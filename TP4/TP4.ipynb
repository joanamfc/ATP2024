# %% [markdown]
# # TP4
# - Crie uma aplicação em Python que coloca no monitor o seguinte menu:
#     * (1) Criar Lista
#     * (2) Ler Lista
#     * (3) Soma
#     * (4) Média
#     * (5) Maior
#     * (6) Menor
#     * (7) estaOrdenada por ordem crescente
#     * (8) estaOrdenada por ordem decrescente
#     * (9) Procura um elemento
#     * (0) Sair
# - O utilizador irá escolher uma das opções introduzindo o número correspondente;
# - Se a opção não for sair, a aplicação executa a operação pretendida, apresenta o resultado e a seguir apresenta de novo o menu;
# - Se a opção for sair, a aplicação termina colocando uma mensagem no monitor.
#
# * No desenvolvimento da aplicação deverá ter em atenção o seguinte:
#     - A aplicação terá uma variável interna para guardar uma lista de números;
#     - Na opção 1, deverá ser criada uma lista de números aleatórios entre 1 e 100 que será guardada na variável interna;
#     - Na opção 2, deverá ser criada uma lista com números introduzidos pelo utilizador, que será guardada na variável interna;
#     - Nestas primeiras opções, se a variável interna já tiver uma lista, esta será sobreposta/apagada pela nova lista;
#     - Na opção 3, será calculada a soma dos elementos na lista no momento;
#     - Na opção 4, será calculada a média dos elementos na lista no momento;
#     - Na opção 5, será calculado o maior elemento da lista no momento;
#     - Na opção 6, será calculado o menor elemento da lista no momento;
#     - Na opção 7, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem crescente;
#     - Na opção 8, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem decrescente;
#     - Na opção 9, a aplicação irá procurar um elemento na lista, se o encontrar deverá devolver a sua posição, devolverá -1 se o elemento não estiver na lista;
#     - Se o utilizador selecionar a opção 0, a aplicação deverá terminar mostrando a lista que está nesse momento guardada.

# %%
import random
nome = input("Insere o teu nome de usário:")
print(f"Olá {nome}, sê bem vindo à aplicação onde podes criar uma lista, ou mandar fazer uma, para depois a manipulares. ")
print("Vamos primeiramente apresentar o que podes fazer nesta aplicação, de seguida seleciona os diferentes número para selecionares o que pretendes fazer.")
print("Opção 1: Deixa connosco! Nós criamos uma lista aleatória com números de 0 a 100 para depois tu a utilizares.")
print("Opção 2: Se preferes fazer tu a tua própria lista, seleciona esta opção, podes escolher o número de elementos e os números que quiseres.")
print("Depois de escolhida a tua lista, podes: ")
print("Opção 3: Se queres somar todos os elementos dessa lista, esta é a opção perfeita para ti. ")
print("Opção 4: Nesta opção vais poder fazer a média dos elementos da lista.")
print("Opção 5: Queres descobrir qual o maior elemento da tua lista? Escolhe esta opção.")
print("Opção 6: E o menor elemento? Esta é a opção para isso.")
print("Opção 7: A minha lista está por ordem crescente? Nós respondemos...")
print("Opção 8: Queres saber se está por ordem decrescente? Escolhe esta opção.")
print("Opção 9: Pensa num elemento, será que ele está na lista? Se estiver vais descobrir a posição do número, se não estiver vais receber o simétrico de 1.")
print(f"Opção 0: Sair da aplicação")
opção = input("Introduz a opção a que queres aceder:")

lista = []

while opção != "0":
    if opção == "1":
        N = int(input("Insere o número de elementos que terá a tua lista:"))
        i = 0
        while len(lista) < N:
            elem = random.randint(0, 101)
            lista.append(elem)
            i = i + 1
        print(f"A lista que contruí foi: {lista}")
        opção = input("Introduz a opção a que queres aceder:")

    elif opção == "2":
        N = int(input("Insere o número de elementos que terá a tua lista:"))
        i = 0
        while len(lista) < N:
            elem = int(input("Introduz o elemento que queres acrescentar na lista:"))
            lista.append(elem)
            i = i + 1
        print(f"A lista que construíste foi: {lista}")
        opção = input("Introduz a opção a que queres aceder:")

    elif opção == "3": 
        soma = 0
        for num in lista:
            soma = soma + num
        print(f"A soma dos elementos da lista é de {soma}")
        opção = input("Introduz a opção a que queres aceder:")  

    elif opção == "4":     
        média = soma / len(lista)
        print(f"A média dos elementos na lista é de {média}.")
        opção = input("Introduz a opção a que queres aceder:")

    elif opção == "5":
        maior = lista[0]
        for num in lista:
            if num > maior:
             maior = num 
        print(f"O maior elemento da lista é {maior}")
        opção = input("Introduz a opção a que queres aceder:")

    elif opção == "6":
        menor = lista[0]
        for num in lista:
            if num < menor:
                menor = num 
        print(f"O menor elemento da lista é {menor}")
        opção = input("Introduz a opção a que queres aceder:")

    elif opção == "7":
        crescente = True
        for i in range(len(lista)-1):
            if lista[i] > lista[i+1]:
                crescente = False
        if crescente:
            print("Sim, a lista está apresentada por ordem crescente.")
        else:
            print("Não, a lista não está apresentada por ordem crescente.")
        opção = input("Introduz a opção a que queres aceder:")


    elif opção == "8":
        decrescente = True
        for i in range(len(lista)-1):
            if lista[i] < lista[i+1]:
                decrescente = False
        if decrescente:
             print("Sim, a lista está apresentada por ordem decrescente.")
        else:
             print("Não, a lista não está apresentada por ordem decrescente.")
        opção = input("Introduz a opção a que queres aceder:")


    elif opção == "9":
        elemento = int(input("Introduz o elemento que queres procurar na lista:"))
        if elemento in lista:
            posição = (lista.index(elemento))
            print(f"O elemento {elemento} encontra-se na lista, na posição {posição}.")
        else:
            print(f"O elemento {elemento} não se encontra na lista.")
            print("-1")
        opção = input("Introduz a opção a que queres aceder:")

print(f"Escolheste sair. Muito obrigada {nome}, volta sempre que quiseres! A lista que ficou guardada: {lista}")
# Out:
# Olá Joana, sê bem vindo à aplicação onde podes criar uma lista, ou mandar fazer uma, para depois a manipulares.
# Vamos primeiramente apresentar o que podes fazer nesta aplicação, de seguida seleciona os diferentes número para selecionares o que pretendes fazer.
# Opção 1: Deixa connosco! Nós criamos uma lista aleatória com números de 0 a 100 para depois tu a utilizares.
# Opção 2: Se preferes fazer tu a tua própria lista, seleciona esta opção, podes escolher o número de elementos e os números que quiseres.
# Depois de escolhida a tua lista, podes:
# Opção 3: Se queres somar todos os elementos dessa lista, esta é a opção perfeita para ti.
# Opção 4: Nesta opção vais poder fazer a média dos elementos da lista.
# Opção 5: Vamos descobrir qual o maior elemento da tua lista? Escolhe esta opção.
# Opção 6: E o menor elemento? Esta é a opção para isso.
# Opção 7: A minha lista está por ordem crescente? Nós respondemos...
# Opção 8: Queres saber se está por ordem decrescente? Escolhe esta opção.
# Opção 9: Pensa num elemento, será que ele está na lista? Se estiver vais descobrir a posição do número, se não estiver vais receber o simétrico de 1.
# Opção 0: Sair da aplicação
# A lista que construíste foi: [1, 5, 9]
# A soma dos elementos da lista é de 15
# A média dos elementos na lista é de 5.0.
# O maior elemento da lista é 9
# O menor elemento da lista é 1
# Sim, a lista está apresentada por ordem crescente.
# Não, a lista não está apresentada por ordem decrescente.
# O elemento 1 encontra-se na lista, na posição 0.
# O elemento 0 não se encontra na lista.
# -1
# Escolheste sair. Muito obrigada Joana, volta sempre que quiseres! A lista que ficou guardada: [1, 5, 9]
